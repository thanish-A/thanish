# %%
print("welcome")
# Out:
# welcome

# %%
print("word")
# Out:
# word

# %%
welcome=input()
print("welcome to home")

# %%
a=int(input())
b=int(input())
print(a+b)

# %%
n=float(input())
print(n)

# %%
a=int(input())
b=int(input())
print("{:.2f}".format(a+b))

# %%
a=int(input())
 
print(hex(a))

# %%
a=int(input())
 
print(oct(a))

# %%
num=0XFF
print(num)

# %%
num = 0o10
print(num)

# %%
a=int(input())
print(ord(a))

# %%
a=int(input())
print(chr(a))

# %%
print(12, 10)

# %%
a=int(input())
b=int(input())
print(a"/t"b)

# %%
a=int(input())
b=int(input())
print(a"/n"b)

# %%
a=int(input())
print("'a'")

# %%
from datetime import datetime
current_time = datetime.now().strftime("%H:%M:%S")
print(current_time)
